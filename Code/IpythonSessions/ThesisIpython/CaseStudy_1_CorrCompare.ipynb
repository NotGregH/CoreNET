# %%
cd ../Networking_Tool/CrossSpeciesTool/
# Out:
# C:\Users\Greg Hamilton\Documents\Vplant\Networking_Tool\CrossSpeciesTool

# %%
import Network_Correlation

# %%
cd ../../TestData/ArabAndRiceData/
# Out:
# C:\Users\Greg Hamilton\Documents\Vplant\TestData\ArabAndRiceData

# %%
####################################
# AraShoots 
####################################

# %%
datadict, gene_arr, line_count, column_count = Network_Correlation.format_expression_data("AraRMADiffShoots.txt")
corr_sif = Network_Correlation.run_corr(datadict, gene_arr, line_count, column_count, pval=None)

# %%
count = 0
for i in corr_sif:
    for l in corr_sif[i]:
        count = count + 1
count
# Out:
# 61075

# %%
originalCorrDiffs = []
diffGenes = []
with open("Ara_1417Nreg_350shoots.cor","rb",-1) as f:
    for line in f:
        line = line.strip().split(",")
        try:
            corr_sif[line[0]][line[1]]
            continue
        except KeyError:
            try:
                corr_sif[line[1]][line[0]]
                continue
            except KeyError:
                diffGenes.append(line[0])
                diffGenes.append(line[1])
                originalCorrDiffs.append((line[0],line[1],line[2],line[3]))
                
diffGenes = list(set(diffGenes))

len(diffGenes)

genes = []
for i in diffGenes:
    try:
        corr_sif[i]
        continue
    except KeyError:
        genes.append(i)
        
nodes = []
for i in corr_sif:
    for l in corr_sif[i]:
        if l not in corr_sif:
            nodes.append(l)
nodes = list(set(nodes))

for i in genes:
    if i not in nodes:
        print i

# %%
diffGenesCounts = {}
for i in diffGenes:
    diffGenesCounts[i] = 0
    for l in originalCorrDiffs:
        if i == l[0]:
            diffGenesCounts[i] = diffGenesCounts[i] + 1
        if i == l[1]:
            diffGenesCounts[i] = diffGenesCounts[i] + 1
diffGenesCounts
# Out:
# {}

# %%
originalCorrDiffs
# Out:
# []

# %%
datadict, gene_arr, line_count, column_count = Network_Correlation.format_expression_data("AraRMADiffShoots.txt")
corr_sif = Network_Correlation.run_corr(datadict, gene_arr, line_count, column_count, pval=0.05)

# %%
count = 0
for i in corr_sif:
    for l in corr_sif[i]:
        count = count + 1
count
# Out:
# 35881

# %%
originalCorrDiffs = []
diffGenes = []
with open("Ara_1417Nreg_350shoots.cor","rb",-1) as f:
    for line in f:
        line = line.strip().split(",")
        try:
            corr_sif[line[0]][line[1]]
            continue
        except KeyError:
            try:
                corr_sif[line[1]][line[0]]
                continue
            except KeyError:
                diffGenes.append(line[0])
                diffGenes.append(line[1])
                originalCorrDiffs.append((line[0],line[1],line[2],line[3]))
                
diffGenes = list(set(diffGenes))

len(diffGenes)

genes = []
for i in diffGenes:
    try:
        corr_sif[i]
        continue
    except KeyError:
        genes.append(i)
        
nodes = []
for i in corr_sif:
    for l in corr_sif[i]:
        if l not in corr_sif:
            nodes.append(l)
nodes = list(set(nodes))

for i in genes:
    if i not in nodes:
        print i

# %%
diffGenesCounts = {}
for i in diffGenes:
    diffGenesCounts[i] = 0
    for l in originalCorrDiffs:
        if i == l[0]:
            diffGenesCounts[i] = diffGenesCounts[i] + 1
        if i == l[1]:
            diffGenesCounts[i] = diffGenesCounts[i] + 1
diffGenesCounts
# Out:
# {'AT1G01140': 3,
#  'AT1G01320': 74,
#  'AT1G02640': 2,
#  'AT1G02660': 1,
#  'AT1G05680': 1,
#  'AT1G07180': 2,
#  'AT1G07610': 2,
#  'AT1G07640': 1,
#  'AT1G08230': 1,
#  'AT1G09850': 1,
#  'AT1G09970': 1,
#  'AT1G10640': 1,
#  'AT1G12580': 2,
#  'AT1G13110': 2,
#  'AT1G13740': 3,
#  'AT1G15690': 2,
#  'AT1G16170': 2,
#  'AT1G18400': 2,
#  'AT1G18620': 1,
#  'AT1G19050': 1,
#  'AT1G19440': 1,
#  'AT1G20640': 2,
#  'AT1G22570': 2,
#  'AT1G24180': 1,
#  'AT1G24280': 1,
#  'AT1G30270': 2,
#  'AT1G30510': 1,
#  'AT1G37130': 1,
#  'AT1G43710': 1,
#  'AT1G49010': 1,
#  'AT1G49500': 1,
#  'AT1G49860': 1,
#  'AT1G51805': 1,
#  'AT1G52190': 1,
#  'AT1G55120': 1,
#  'AT1G55960': 2,
#  'AT1G58180': 2,
#  'AT1G60140': 1,
#  'AT1G60960': 2,
#  'AT1G61820': 1,
#  'AT1G62770': 2,
#  'AT1G64190': 1,
#  'AT1G64590': 1,
#  'AT1G65870': 3,
#  'AT1G66130': 1,
#  'AT1G69160': 2,
#  'AT1G69490': 2,
#  'AT1G69850': 3,
#  'AT1G70780': 1,
#  'AT1G71010': 1,
#  'AT1G73600': 1,
#  'AT1G73920': 1,
# ...

# %%
len(originalCorrDiffs)
# Out:
# 323

# %%
originalCorrDiffs
# Out:
# [('AT1G01320', 'AT1G01140', '0.967794810711689', '0.0322051892883108'),
#  ('AT4G09900', 'AT1G01140', '0.990883512004758', '0.0091164879952419'),
#  ('AT5G47400', 'AT1G01140', '0.961683117591707', '0.0383168824082927'),
#  ('AT1G02660', 'AT1G01320', '0.972304768620151', '0.0276952313798486'),
#  ('AT1G07180', 'AT1G01320', '0.970535584660187', '0.0294644153398127'),
#  ('AT1G10640', 'AT1G01320', '0.960685049281221', '0.0393149507187793'),
#  ('AT1G13110', 'AT1G01320', '0.982618538106551', '0.0173814618934487'),
#  ('AT1G20640', 'AT1G01320', '0.974085068426145', '0.0259149315738547'),
#  ('AT1G22570', 'AT1G01320', '0.980318152198659', '0.0196818478013414'),
#  ('AT1G52190', 'AT1G01320', '0.958287982594686', '0.0417120174053138'),
#  ('AT1G69160', 'AT1G01320', '0.951876117518956', '0.0481238824810442'),
#  ('AT1G69850', 'AT1G01320', '0.967391643689839', '0.0326083563101611'),
#  ('AT1G78290', 'AT1G01320', '0.976493734324484', '0.0235062656755165'),
# ...

# %%
corr_sif['AT1G01140']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-c8d094aeb014> in <module>()
# ----> 1 corr_sif['AT1G01140']['AT4G09900']
#
# KeyError: 'AT4G09900'

# %%
###  Should be 36,139 so off by :
36139 - 35881
# Out:
# 258

# %%
corr_sif["AT1G01140"]["AT2G32560"]
# Out:
# ['corr:0.9573::pval:0.0426867684964']

# %%
###################### ####################################################################
## The Method for consolidating the multiple probe genes is definitely taking the mean 
## SO the problem has to be the mapping file 
#########################################################################################

# %%
###############################
# Back from taking all of 
# probes for each gene
# Let's find the exact changes
###############################

# %%
originalCorrDiffs = []
diffGenes = []
with open("Ara_1417Nreg_350shoots.cor","rb",-1) as f:
    for line in f:
        line = line.strip().split(",")
        try:
            corr_sif[line[0]][line[1]]
            continue
        except KeyError:
            try:
                corr_sif[line[1]][line[0]]
                continue
            except KeyError:
                diffGenes.append(line[0])
                diffGenes.append(line[1])
                originalCorrDiffs.append((line[0],line[1],line[2],line[3]))
                
diffGenes = list(set(diffGenes))

len(diffGenes)

# %%
len(originalCorrDiffs) # Huh?

# %%
oringinalCorrDiffs = list(set(originalCorrDiffs)) 
len(originalCorrDiffs)

# %%
genes = []
for i in diffGenes:
    try:
        corr_sif[i]
        continue
    except KeyError:
        genes.append(i)
len(genes) # only two genes maybe not present

# %%
nodes = []
for i in corr_sif:
    for l in corr_sif[i]:
        if l not in corr_sif:
            nodes.append(l)
nodes = list(set(nodes))

for i in genes:
    if i not in nodes:
        print i
### All genes accounted for....

# %%
originalCorrDiffs

# %%
diffGenesCounts = {}
for i in diffGenes:
    diffGenesCounts[i] = 0
    for l in originalCorrDiffs:
        if i == l[0]:
            diffGenesCounts[i] = diffGenesCounts[i] + 1
        if i == l[1]:
            diffGenesCounts[i] = diffGenesCounts[i] + 1

# %%
diffGenesCounts

# %%
# 'AT1G01320': 74
# 'AT3G53670': 118
# 'AT4G09900': 96
# 'AT5G47400': 35

# %%
## Lets check if these are genes that have more than one spot in the normalized data

# %%
AT1G01320 = 0
AT3G53670 = 0
AT4G09900 = 0
AT5G47400 = 0
with open("Ara_RMAnorm_DiffGenes.txt","rb",-1) as f:
    for line in f:
        line = line.strip().split("\t")
        if line[0] == "AT1G01320":
            AT1G01320 = AT1G01320 + 1
        if line[0] == "AT3G53670":
            AT3G53670 = AT3G53670 + 1
        if line[0] == "AT4G09900":
            AT4G09900 = AT4G09900 + 1
        if line[0] == "AT5G47400":
            AT5G47400 = AT5G47400 + 1

# %%
AT1G01320

# %%
AT3G53670

# %%
AT4G09900

# %%
AT5G47400

# %%
####################################
# AraRoots
####################################

# %%
datadict, gene_arr, line_count, column_count = Network_Correlation.format_expression_data("AraRMADiffRoots.txt")
corr_sif = Network_Correlation.run_corr(datadict, gene_arr, line_count, column_count, pval=None)

# %%
count = 0
for i in corr_sif:
    for l in corr_sif[i]:
        count = count + 1
count

# %%
datadict, gene_arr, line_count, column_count = Network_Correlation.format_expression_data("AraRMADiffRoots.txt")
corr_sif = Network_Correlation.run_corr(datadict, gene_arr, line_count, column_count, pval=0.05)

# %%
count = 0
for i in corr_sif:
    for l in corr_sif[i]:
        count = count + 1
count

# %%
###  Should be 417,805 so off by :
417805 - 414211

# %%
#### Need to find the differences

# %%
corr_sif["AT5G67470"]["ATMG00140"] ## Matches exactly with the correlation done 
# fot the paper , indicating the issues is not with the calculation

# %%
corr_sif["AT5G67430"] ["AT5G67470"]## Matches exactly with the correlation done 
# fot the paper , indicating the issues is not with the calculation

# %%
corr_sif ["AT5G64290"]["ATMG00140"]## Matches exactly with the correlation done 
# fot the paper , indicating the issues is not with the calculation

# %%
### Three in a row at random so where is the difference? Need to check if the
# corr file from paper has been filtered for .05 pval

# %%
AT5G67290,AT5G62720 # these are close to 0.05 (i.e. 0.0499)

# %%
corr_sif["AT5G62720"]["AT5G67290"]

# %%
####################################
# RiceShoots
####################################
# 3/24/16 rerunning this part to do a more comprehensive comparison like I did with arabidopsis shoots

# %%
datadict, gene_arr, line_count, column_count = Network_Correlation.format_expression_data("RiceRMADiffShoots.txt")
corr_sif = Network_Correlation.run_corr(datadict, gene_arr, line_count, column_count)
count = 0
for i in corr_sif:
    for l in corr_sif[i]:
        count = count + 1
count

# %%
datadict, gene_arr, line_count, column_count = Network_Correlation.format_expression_data("RiceRMADiffShoots.txt")
corr_sif = Network_Correlation.run_corr(datadict, gene_arr, line_count, column_count, pval=0.05)
count = 0
for i in corr_sif:
    for l in corr_sif[i]:
        count = count + 1
count
#### Again a difference :

# %%
4053 - 3846

# %%
originalCorrDiffs = []
diffGenes = []
with open("Rice_451Nreg_142shoots.cor","rb",-1) as f:
    for line in f:
        line = line.strip().split(",")
        try:
            corr_sif[line[0]][line[1]]
            continue
        except KeyError:
            try:
                corr_sif[line[1]][line[0]]
                continue
            except KeyError:
                diffGenes.append(line[0])
                diffGenes.append(line[1])
                originalCorrDiffs.append((line[0],line[1],line[2],line[3]))
                
diffGenes = list(set(diffGenes))

len(diffGenes)

# %%
len(originalCorrDiffs)

# %%
originalCorrDiffs

# %%
corr_sif['LOC_OS02G40200']

# %%
corr_sif["LOC_OS02G40200"]

# %%
#LOC_OS12G14540,LOC_OS02G40200,0.975957711888299,0.0240422881117008

# %%
diffGene

# %%
genes = []
for i in diffGenes:
    try:
        corr_sif[i]
        continue
    except KeyError:
        genes.append(i)

# %%
nodes = []
for i in corr_sif:
    for l in corr_sif[i]:
        if l not in corr_sif:
            nodes.append(l)
nodes = list(set(nodes))

for i in genes:
    if i not in nodes:
        print i
### All genes accounte

# %%
diffGenesCounts = {}
for i in diffGenes:
    diffGenesCounts[i] = 0
    for l in originalCorrDiffs:
        if i == l[0]:
            diffGenesCounts[i] = diffGenesCounts[i] + 1
        if i == l[1]:
            diffGenesCounts[i] = diffGenesCounts[i] + 1

# %%
diffGenesCounts

# %%
####################################
# RiceRoots
#################################### 
# 3/24/16 rerunning this part to do a more comprehensive comparison like I did with arabidopsis shoots

# %%
datadict, gene_arr, line_count, column_count = Network_Correlation.format_expression_data("RiceRMADiffRoots.txt")
corr_sif = Network_Correlation.run_corr(datadict, gene_arr, line_count, column_count)
count = 0
for i in corr_sif:
    for l in corr_sif[i]:
        count = count + 1
count

# %%
datadict, gene_arr, line_count, column_count = Network_Correlation.format_expression_data("RiceRMADiffRoots.txt")
corr_sif = Network_Correlation.run_corr(datadict, gene_arr, line_count, column_count, pval=0.05)
count = 0
for i in corr_sif:
    for l in corr_sif[i]:
        count = count + 1
count

# %%
#### Again a difference :
28482 - 26456
# Out:
# 2026

# %%
#################################################################################
# Possible Reasons for the difference:
# - The method for consolidating multiple probes for a single gene is different
# - Caculations issues ( unlikely though )
#################################################################################

# %%
##################################################################################
# Returning to the filtering script then coming back for a new comparison 
##################################################################################

# %%
#####################
# Now with all genes 
# for every probe
#####################

# %%
####################################
# AraShoots 
####################################

# %%
datadict, gene_arr, line_count, column_count = Network_Correlation.format_expression_data("AraRMAallShoots.txt")
corr_sif = Network_Correlation.run_corr(datadict, gene_arr, line_count, column_count, pval=None)
count = 0
for i in corr_sif:
    for l in corr_sif[i]:
        count = count + 1
count

# %%
datadict, gene_arr, line_count, column_count = Network_Correlation.format_expression_data("AraRMAallShoots.txt")
corr_sif = Network_Correlation.run_corr(datadict, gene_arr, line_count, column_count, pval=0.05)
count = 0
for i in corr_sif:
    for l in corr_sif[i]:
        count = count + 1
count

# %%
###  Should be 36,139 so off by :
36139 - 35659 
### off by more so definitely not it
# Out:
# 480

# %%
###################################
# Maybe the max for each gene? - 
###################################

# %%
datadict, gene_arr, line_count, column_count = Network_Correlation.format_expression_data("AraRMAMaxShoots.txt")
corr_sif = Network_Correlation.run_corr(datadict, gene_arr, line_count, column_count, pval=None)
count = 0
for i in corr_sif:
    for l in corr_sif[i]:
        count = count + 1
count
# Out:
# 61075

# %%
datadict, gene_arr, line_count, column_count = Network_Correlation.format_expression_data("AraRMAMaxShoots.txt")
corr_sif = Network_Correlation.run_corr(datadict, gene_arr, line_count, column_count, pval=0.05)
count = 0
for i in corr_sif:
    for l in corr_sif[i]:
        count = count + 1
count
# Out:
# 36198

# %%
# We are now over the amount
# so the truth lies somewhere inbetween

# %%
#AT1G20640,AT1G01140,0.999169533118412,0.000830466881587721
corr_sif["AT1G01140"]["AT1G20640"] # rounded to one
# Out:
# ['corr:0.9992::pval:0.000830466881517']

# %%
originalCorrDiffs = []
diffGenes = []
with open("Ara_1417Nreg_350shoots.cor","rb",-1) as f:
    for line in f:
        line = line.strip().split(",")
        try:
            corr_sif[line[0]][line[1]]
            continue
        except KeyError:
            try:
                corr_sif[line[1]][line[0]]
                continue
            except KeyError:
                diffGenes.append(line[0])
                diffGenes.append(line[1])
                originalCorrDiffs.append((line[0],line[1],line[2],line[3]))
                
diffGenes = list(set(diffGenes))

len(diffGenes)

genes = []
for i in diffGenes:
    try:
        corr_sif[i]
        continue
    except KeyError:
        genes.append(i)
        
nodes = []
for i in corr_sif:
    for l in corr_sif[i]:
        if l not in corr_sif:
            nodes.append(l)
nodes = list(set(nodes))

for i in genes:
    if i not in nodes:
        print i

# %%
diffGenesCounts = {}
for i in diffGenes:
    diffGenesCounts[i] = 0
    for l in originalCorrDiffs:
        if i == l[0]:
            diffGenesCounts[i] = diffGenesCounts[i] + 1
        if i == l[1]:
            diffGenesCounts[i] = diffGenesCounts[i] + 1
diffGenesCounts
# Out:
# {'AT1G66820': 1,
#  'AT1G73870': 1,
#  'AT2G32560': 4,
#  'AT3G10910': 1,
#  'AT3G21520': 1,
#  'AT3G53670': 1,
#  'AT4G00700': 1,
#  'AT5G10310': 1,
#  'AT5G54130': 3}

# %%
diffGenes
# Out:
# ['AT3G53670',
#  'AT4G00700',
#  'AT1G73870',
#  'AT3G21520',
#  'AT5G10310',
#  'AT3G10910',
#  'AT2G32560',
#  'AT1G66820',
#  'AT5G54130']

# %%
originalCorrDiffs
# Out:
# [('AT2G32560', 'AT1G66820', '0.962089903985715', '0.0379100960142851'),
#  ('AT2G32560', 'AT1G73870', '0.956671689646264', '0.0433283103537354'),
#  ('AT3G21520', 'AT2G32560', '0.953360379250115', '0.0466396207498847'),
#  ('AT3G10910', 'AT2G32560', '-0.957864496429898', '0.0421355035701024'),
#  ('AT5G54130', 'AT3G53670', '-0.968394602069704', '0.0316053979302965'),
#  ('AT5G54130', 'AT4G00700', '0.973569789274779', '0.0264302107252206'),
#  ('AT5G54130', 'AT5G10310', '-0.975027294359309', '0.0249727056406907')]

# %%
corr_sif['AT2G32560']['AT1G66820']
# Out:
# ['corr:0.9621::pval:0.0379100960162']

# %%
###########################################
# Trying taking the top level
###########################################

# %%
datadict, gene_arr, line_count, column_count = Network_Correlation.format_expression_data("AraRMATopShoots.txt")
corr_sif = Network_Correlation.run_corr(datadict, gene_arr, line_count, column_count, pval=None)
count = 0
for i in corr_sif:
    for l in corr_sif[i]:
        count = count + 1
count
# Out:
# 61075

# %%
datadict, gene_arr, line_count, column_count = Network_Correlation.format_expression_data("AraRMATopShoots.txt")
corr_sif = Network_Correlation.run_corr(datadict, gene_arr, line_count, column_count, pval=0.05)
count = 0
for i in corr_sif:
    for l in corr_sif[i]:
        count = count + 1
count
# Out:
# 35543

# %%
###########################################
# Trying taking the highest avg level
###########################################

# %%
datadict, gene_arr, line_count, column_count = Network_Correlation.format_expression_data("AraRMAMaxAvgShoots.txt")
corr_sif = Network_Correlation.run_corr(datadict, gene_arr, line_count, column_count, pval=None)
count = 0
for i in corr_sif:
    for l in corr_sif[i]:
        count = count + 1
count
# Out:
# 61075

# %%
datadict, gene_arr, line_count, column_count = Network_Correlation.format_expression_data("AraRMAMaxAvgShoots.txt")
corr_sif = Network_Correlation.run_corr(datadict, gene_arr, line_count, column_count, pval=0.05)
count = 0
for i in corr_sif:
    for l in corr_sif[i]:
        count = count + 1
count
# Out:
# 36198

# %%
originalCorrDiffs = []
diffGenes = []
with open("Ara_1417Nreg_350shoots.cor","rb",-1) as f:
    for line in f:
        line = line.strip().split(",")
        try:
            corr_sif[line[0]][line[1]]
            continue
        except KeyError:
            try:
                corr_sif[line[1]][line[0]]
                continue
            except KeyError:
                diffGenes.append(line[0])
                diffGenes.append(line[1])
                originalCorrDiffs.append((line[0],line[1],line[2],line[3]))
                
diffGenes = list(set(diffGenes))

len(diffGenes)
# Out:
# 9

# %%
diffGenes
# Out:
# ['AT3G53670',
#  'AT4G00700',
#  'AT1G73870',
#  'AT3G21520',
#  'AT5G10310',
#  'AT3G10910',
#  'AT2G32560',
#  'AT1G66820',
#  'AT5G54130']

# %%
genes = []
for i in diffGenes:
    try:
        corr_sif[i]
        continue
    except KeyError:
        genes.append(i)
        
nodes = []
for i in corr_sif:
    for l in corr_sif[i]:
        if l not in corr_sif:
            nodes.append(l)
nodes = list(set(nodes))

for i in genes:
    if i not in nodes:
        print i

# %%
diffGenesCounts = {}
for i in diffGenes:
    diffGenesCounts[i] = 0
    for l in originalCorrDiffs:
        if i == l[0]:
            diffGenesCounts[i] = diffGenesCounts[i] + 1
        if i == l[1]:
            diffGenesCounts[i] = diffGenesCounts[i] + 1
diffGenesCounts
# Out:
# {'AT1G66820': 1,
#  'AT1G73870': 1,
#  'AT2G32560': 4,
#  'AT3G10910': 1,
#  'AT3G21520': 1,
#  'AT3G53670': 1,
#  'AT4G00700': 1,
#  'AT5G10310': 1,
#  'AT5G54130': 3}

# %%
originalCorrDiffs
# Out:
# [('AT2G32560', 'AT1G66820', '0.962089903985715', '0.0379100960142851'),
#  ('AT2G32560', 'AT1G73870', '0.956671689646264', '0.0433283103537354'),
#  ('AT3G21520', 'AT2G32560', '0.953360379250115', '0.0466396207498847'),
#  ('AT3G10910', 'AT2G32560', '-0.957864496429898', '0.0421355035701024'),
#  ('AT5G54130', 'AT3G53670', '-0.968394602069704', '0.0316053979302965'),
#  ('AT5G54130', 'AT4G00700', '0.973569789274779', '0.0264302107252206'),
#  ('AT5G54130', 'AT5G10310', '-0.975027294359309', '0.0249727056406907')]

# %%
corr_sif["AT1G01140"]["AT2G32560"]
# Out:
# ['corr:0.9706::pval:0.0294406316649']
